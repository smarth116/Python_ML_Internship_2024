# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
sm=pd.read_csv('student_marks.csv')
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
# [559 rows x 7 columns]

# %%
sm['Total']=sm[['English','Hindi','Maths','Science','SST']].sum(axis=1)
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      Total
# 0      306
# 1      365
# 2      155
# 3      257
# ...

# %%
sm['Percentage']=sm['Total']/5

# %%
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      Total  Percentage
# 0      306        61.2
# ...

# %%
def determine_grade(percentage):
    if percentage >= 90:
        return 'A+'
    elif percentage >= 80:
        return 'A'
    elif percentage >= 70:
        return 'B+'
    elif percentage >= 60:
        return 'B'
    elif percentage >= 50:
        return 'C'
    elif percentage >= 35:
        return 'D'
    else:
        return 'F'

sm['Grade'] = sm['Percentage'].apply(determine_grade)
sm
# Out:
#      Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0          1            A HariCharan        80     66     98       21   41
# 1          2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2          3           A Pavan Kumar        41     46     26        7   35
# 3          4            Aaditya Nanda       64     99      6       16   72
# 4          5        Aakanksha Kaushal       38     20     40       33   50
# ..       ...                      ...      ...    ...    ...      ...  ...
# 554      555           Yamini Priya K       57     52     77       95   77
# 555      556         YARUKALA ALEKHYA       11     24     18       28    5
# 556      557           YOGESH KOTHARI        8     12     29       32   32
# 557      558       ZAKKAM ABHIGNA RAJ       85     72     97       90   79
# 558      559               Zoha Shaik       95     86     59       81   77
#
#      Total  Percentage Grade
# 0      306        61.2     B
# ...

# %%
Temp=sm.head()
Temp
# Out:
#    Roll No                     Name  English  Hindi  Maths  Science  SST  \
# 0        1            A HariCharan        80     66     98       21   41
# 1        2  A Mohammed Sahil Aiyan        72     73     81       56   83
# 2        3           A Pavan Kumar        41     46     26        7   35
# 3        4            Aaditya Nanda       64     99      6       16   72
# 4        5        Aakanksha Kaushal       38     20     40       33   50
#
#    Total  Percentage Grade
# 0    306        61.2     B
# 1    365        73.0    B+
# 2    155        31.0     F
# 3    257        51.4     C
# 4    181        36.2     D

# %%
colors = {
    'English': 'red',
    'Hindi': 'blue',
    'Maths': 'green',
    'Science': 'purple',
    'SST': 'orange'
}
for sub in ['English','Hindi','Maths','Science','SST']:
    plt.figure(figsize=(10,6))
    plt.plot(Temp['Name'],Temp[sub],marker='o',label=sub,color=colors[sub])
    plt.title("Marks in different Subjects")
    plt.xlabel('Name')
    plt.ylabel('Marks')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
sub=['English','Hindi','Maths','Science','SST']
plt.figure(figsize=(10,6))
plt.plot(Temp['Name'],Temp[sub],marker='o',label=sub)
plt.title("Marks in different Subjects")
plt.xlabel('Name')
plt.ylabel('Marks')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt .figure(figsize=(10,5))
a1=plt.bar(Temp['Name'],Temp['English'],label="English",colour='b')
b1=plt.bar(Temp['Name'],Temp['Hindi'],label="English",colour='g')
c1=plt.bar(Temp['Name'],Temp['Maths'],label="English",colour='y')
d1plt.bar(Temp['Name'],Temp['Science'],label="English",colour='r')
e1=plt.bar(Temp['Name'],Temp['SST'],label="English",colour='b')
plt.title("marksin english subject ",fontsize=20)
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 plt .figure(figsize=(10,5))
# ----> 2 a1=plt.bar(Temp['Name'],Temp['English'],label="English",colour='b')
#       3 b1=plt.bar(Temp['Name'],Temp['Hindi'],label="English",colour='g')
#       4 c1=plt.bar(Temp['Name'],Temp['Maths'],label="English",colour='y')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2956, in bar(x, height, width, bottom, align, data, **kwargs)
#    2945 @_copy_docstring_and_deprecators(Axes.bar)
#    2946 def bar(
#    2947     x: float | ArrayLike,
#    (...)
#    2954     **kwargs,
#    2955 ) -> BarContainer:
# -> 2956     return gca().bar(
#    2957         x,
#    2958         height,
#    2959         width=width,
#    2960         bottom=bottom,
#    2961         align=align,
# ...

# %%
sub=['English','Hindi','Maths','Science','SST']
plt.figure(figsize=(10,5))
plt.bar(Temp['Name'],Temp[sub],label="sub")
plt.title("Marks in different Subjects")
plt.xlabel('Name')
plt.ylabel('Marks')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 sub=['English','Hindi','Maths','Science','SST']
#       2 plt.figure(figsize=(10,5))
# ----> 3 plt.bar(Temp['Name'],Temp[sub],label="sub")
#       4 plt.title("Marks in different Subjects")
#       5 plt.xlabel('Name')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:2956, in bar(x, height, width, bottom, align, data, **kwargs)
#    2945 @_copy_docstring_and_deprecators(Axes.bar)
#    2946 def bar(
#    2947     x: float | ArrayLike,
#    (...)
#    2954     **kwargs,
#    2955 ) -> BarContainer:
# -> 2956     return gca().bar(
#    2957         x,
#    2958         height,
#    2959         width=width,
#    2960         bottom=bottom,
#    2961         align=align,
#    2962         **({"data": data} if data is not None else {}),
#    2963         **kwargs,
# ...
